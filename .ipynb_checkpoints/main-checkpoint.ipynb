# %% [markdown]
# # Yad2 Web Scraping
# <img src="images/yad2Logo.png" alt="drawing" width="300"/>

# %% [markdown]
# ### Goals:
# 1) Scrap data to local computer for price statistics according to various parameters (area, number of rooms, floor, city and neighborhood).
# 2) Create An interactive heat map for a convenient comparison of prices by area and house data as following:

# %% [markdown]
# <img src="images/heat_map_example.png" alt="drawing" width="300"/>

# %%
from general_scraper import *
# Out:
# Created HEADERS:
# {'Accept': 'application/json, text/plain, */*', 'Accept-Encoding': 'gzip, deflate, br', 'Accept-Language': 'he-IL,he;q=0.9,en-US;q=0.8,en;q=0.7', 'Connection': 'keep-alive', 'Host': 'www.yad2.co.il', 'mobile-app': 'false', 'Referer': 'https://www.yad2.co.il/realestate/forsale', 'sec-ch-ua': '"Google Chrome";v="107", "Chromium";v="107", "Not=A?Brand";v="24"', 'sec-ch-ua-platform': '"Windows"', 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36', 'Cookie': '__uzma=12133d30-5e46-41fb-ae39-938f5f74f2a6; __uzmb=1668338056; __uzmc=508091014538; __uzmd=1668338056; __uzme=4025; '}

# %% [markdown]
# ## Get data of posts from first 1000 pages (orderd by date)

# %%
# change "last_page_num" to the count of pages you want to scrape
last_page_num = 10

# %% [markdown]
# ## Convert to pandas DataFrame

# %%
df = get_posts_DataFrame(last_page_num=last_page_num)
df
# Out:
#        price              address         city        type  rooms  floor  \
# 0     850000             יד ושם 4      באר שבע        דירה      4      2
# 1    2360000          משה פריד 39       רחובות        דירה      3      6
# 2    2290000          מבוא חרוב 8     צור הדסה  גג/פנטהאוז      4      3
# 3    2640000          יעקב תמרי 8       רחובות        דירה      4     14
# 4    1836000  שדרות ששת הימים 327         אילת        דירה      3      3
# ..       ...                  ...          ...         ...    ...    ...
# 162  5180000             תל יהודה       רמת גן  גג/פנטהאוז      5      6
# 163  4350000          נווה אביבים  תל אביב יפו        דירה      4      3
# 164  3950000                אגמים        נתניה        דירה      5     13
# 165  7800000        תכנית ל', למד  תל אביב יפו        דירה      5      6
# 166  3995000      שדרות בן גוריון        חולון  גג/פנטהאוז      6      7
#
#      size      update  scrap_date
# 0      82  2022/11/13  2022/11/13
# ...

# %% [markdown]
# ## Save to your local computer

# %%
df.to_excel('Houses.xlsx', index=False)

# %% [markdown]
# # Result
# 1) Upload the table to [your own Google Sheets](https://docs.google.com/spreadsheets/u/0/).
# 2) Build a dashbord in [google Looker (data studio)](https://datastudio.google.com/u/0/).
# 3) Visit my [dashbord](https://datastudio.google.com/embed/reporting/90738cd2-b077-4b71-9b46-25bb2ce8e4c6/page/V806C)! (takes a few seconds)

# %%
from bs4 import BeautifulSoup
import re

# %%
def get_car_data(car) -> dict:
    brand = car.find('span', class_='title').text.strip()
    brand2 = car.find('span', class_='subtitle').text.strip()
    price = car.find('div', class_='price').text.strip()
    year = car.find('div', class_='data year-item').find('span', class_='val').text
    hand = car.find('div', class_='data hand-item').find('span', class_='val').text
    engine_size = car.find('div', class_='data engine_size-item').find('span', class_='val').text
    
    # additional
    brac1 = brand2.find('(')
    brac2 = brand2.find(')')
    hourse_power = brand2[brac1+1 : brac2].replace("כ''ס", '')
#     fuel = 
#     seats = 
    automatic_trans = brand2.find("ידני") < 0
    
    brand2 = brand2.replace("אוט' ", '') if automatic_trans else brand2.replace("ידני ", '')
    
    result = {
        'brand': brand,
        'brand2': brand2,
        'price': price,
        'year': year,
        'hand': hand,
        'engine_size': engine_size,
        'automatic_trans': automatic_trans,
        'hourse_power': hourse_power
    }
    return result

# %%
def get_cars_page_data(cars_page):
    return [get_car_data(car) for car in cars_page_1]

# %%
cars_page_1 = get_feeditems(1, 'vehicles/cars')

# %%
df = pd.json_normalize(get_cars_page_data(cars_page_1))
df
# Out:
#                           brand                                      brand2  \
# 0                      אאודי Q2                      Comfort 1.5 (150 כ''ס)
# 1             מיצובישי אאוטלנדר                 Instyle 7 מק' 2.0 (150 כ"ס)
# 2                   סקודה קאמיק                     Ambition 1.0 (115 כ''ס)
# 3        מיצובישי אאוטלנדר PHEV      4X4 Luxury הייבריד 5 מק' 2.0 (121 כ"ס)
# 4              פולקסווגן טיגואן                     Trendline 1.4 (150 כ"ס)
# 5                  שברולט סוניק                      RS הצ'בק 1.4 (140 כ"ס)
# 6                 סקודה אוקטביה                     Elegance 1.4 (140 כ''ס)
# 7                   סקודה קארוק                   Style דיזל 1.6 (115 כ''ס)
# 8             טויוטה ספייס ורסו                            GLI 1.3 (99 כ"ס)
# 9   רנו קליאו דור 4 (2013-2019)                   Collection 1.2 (118 כ''ס)
# 10          סוזוקי SX4 קרוסאובר                          GLX 1.6 (118 כ''ס)
# ...

# %%
cars_page_1[0]
# Out:
# <div class="feeditem table" data-v-62c3108a=""><div class="feed_item feed_item-v4 accordion desktop" data-v-62c3108a="" id="feed_item_0" item-id="m34jwfwh"><div class="color_container yellow"><div class="right_col"><div class="image_container"><!-- --> <!-- --> <div class="like-btn"><div class="like_icon_wrapper" data-v-d7eeb5fa=""><button class="like_icon y2i_like" data-test-id="LIKE_AD" data-v-d7eeb5fa=""></button> <!-- --></div></div> <!-- --> <div class="pic" id="image_0"><img alt="" class="feedImage" src="https://img.yad2.co.il/Pic/202208/19/1_3/o/y2_1_03076_20220819001524.jpeg?l=5&amp;c=3&amp;w=195&amp;h=117" title=""/> <div class="icons"><!-- --> <div class="icon image-index"><img alt="" src="//assets.yad2.co.il/yad2site/y2assets/images/images-gallery/PIC.svg"/> <span class="count">6</span></div></div></div></div> <div class="rows"><span id="feed_item_0_title"><span class="title">
#                         ניסאן אקס טרייל
# ...
